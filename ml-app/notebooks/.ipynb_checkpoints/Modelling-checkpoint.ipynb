# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
from sklearn.ensemble import RandomForestRegressor as RF
from sklearn.metrics import mean_absolute_error, mean_squared_error
import warnings 
warnings.filterwarnings('ignore')

# %% [markdown]
# # Data Prepration

# %%
data = pd.read_parquet('/Users/sameernigam/Desktop/ml-end-end-project/data/raw_data/database.parquet')

# %%
data.head()
# Out:
#               datetime  season  yr  mnth  hr  holiday  weekday  workingday  \
# 0  2011-01-01 00:00:00       1   0     1   0        0        6           0
# 1  2011-01-01 01:00:00       1   0     1   1        0        6           0
# 2  2011-01-01 02:00:00       1   0     1   2        0        6           0
# 3  2011-01-01 03:00:00       1   0     1   3        0        6           0
# 4  2011-01-01 04:00:00       1   0     1   4        0        6           0
#
#    weathersit  temp   atemp   hum  windspeed  casual  registered  cnt
# 0           1  0.24  0.2879  0.81        0.0       3          13   16
# 1           1  0.22  0.2727  0.80        0.0       8          32   40
# 2           1  0.22  0.2727  0.80        0.0       5          27   32
# 3           1  0.24  0.2879  0.75        0.0       3          10   13
# 4           1  0.24  0.2879  0.75        0.0       0           1    1

# %%
data.tail()
# Out:
#                   datetime  season  yr  mnth  hr  holiday  weekday  \
# 13898  2012-08-07 07:00:00       3   1     8   7        0        2
# 13899  2012-08-07 08:00:00       3   1     8   8        0        2
# 13900  2012-08-07 09:00:00       3   1     8   9        0        2
# 13901  2012-08-07 10:00:00       3   1     8  10        0        2
# 13902  2012-08-07 11:00:00       3   1     8  11        0        2
#
#        workingday  weathersit  temp   atemp   hum  windspeed  casual  \
# 13898           1           2  0.70  0.6667  0.74     0.1343      21
# 13899           1           2  0.70  0.6515  0.70     0.1642      41
# 13900           1           2  0.70  0.6667  0.74     0.1343      44
# 13901           1           2  0.74  0.6970  0.70     0.1343      89
# 13902           1           2  0.76  0.7273  0.66     0.0896      84
#
#        registered  cnt
# 13898         481  502
# 13899         664  705
# 13900         283  327
# 13901         161  250
# 13902         130  214

# %%
drop_cols = ['yr', 'casual', 'registered', 'datetime']

# %%
data = data.drop(columns = drop_cols)

# %%
data.head()
# Out:
#    season  mnth  hr  holiday  weekday  workingday  weathersit  temp   atemp  \
# 0       1     1   0        0        6           0           1  0.24  0.2879
# 1       1     1   1        0        6           0           1  0.22  0.2727
# 2       1     1   2        0        6           0           1  0.22  0.2727
# 3       1     1   3        0        6           0           1  0.24  0.2879
# 4       1     1   4        0        6           0           1  0.24  0.2879
#
#     hum  windspeed  cnt
# 0  0.81        0.0   16
# 1  0.80        0.0   40
# 2  0.80        0.0   32
# 3  0.75        0.0   13
# 4  0.75        0.0    1

# %% [markdown]
# # Baseline Model
#
# Metrics - MAPE = Mean Absolute Percentage Error
#         - MAE
#         - RMSE

# %%
def compute_metrics(y_true, y_pred):

    '''Purpose:
Calculates three common error metrics to evaluate prediction models: MAE, RMSE, and MAPE.

Parameters:

y_true (list or array): The actual true values from your dataset.

y_pred (list or array): The predicted values from your model.'''

    
    mae = mean_absolute_error(y_true, y_pred)
    rmse =  mean_squared_error(y_true, y_pred)

    y_true = np.array(y_true)
    y_pred = np.array(y_pred)


    mape = np.mean(np.abs((y_true - y_pred) / np.where(y_true == 0, 0.01, y_true))) * 100


    return{
        'MAE': round(mae, 2),
        'RMSE': round(rmse, 2),
        'MAPE': round(mape, 2)
    }

# %%
data.shape[0]
# Out:
# 13903

# %%
def prepare_dataset(df, train_fraction):
    feats  = [col for col in df.columns if col!= 'target']
    x, y = df[feats], df['target']
    train_size = int(train_fraction * df.shape[0])
    x_train, x_test = x[:train_size], x[train_size:]
    y_train, y_test = y[:train_size], y[train_size:]

    return x_train, x_test, y_train, y_test

# %% [markdown]
# # Target Defination

# %%
df = data.copy()

# %%
df['target'] = df['cnt'].shift(-1).fillna(method = 'ffill')
df.drop(columns = ['cnt'], inplace = True)

# %%
df.head()
# Out:
#    season  mnth  hr  holiday  weekday  workingday  weathersit  temp   atemp  \
# 0       1     1   0        0        6           0           1  0.24  0.2879
# 1       1     1   1        0        6           0           1  0.22  0.2727
# 2       1     1   2        0        6           0           1  0.22  0.2727
# 3       1     1   3        0        6           0           1  0.24  0.2879
# 4       1     1   4        0        6           0           1  0.24  0.2879
#
#     hum  windspeed  target
# 0  0.81        0.0    40.0
# 1  0.80        0.0    32.0
# 2  0.80        0.0    13.0
# 3  0.75        0.0     1.0
# 4  0.75        0.0     1.0

# %%
df.tail()
# Out:
#        season  mnth  hr  holiday  weekday  workingday  weathersit  temp  \
# 13898       3     8   7        0        2           1           2  0.70
# 13899       3     8   8        0        2           1           2  0.70
# 13900       3     8   9        0        2           1           2  0.70
# 13901       3     8  10        0        2           1           2  0.74
# 13902       3     8  11        0        2           1           2  0.76
#
#         atemp   hum  windspeed  target
# 13898  0.6667  0.74     0.1343   705.0
# 13899  0.6515  0.70     0.1642   327.0
# 13900  0.6667  0.74     0.1343   250.0
# 13901  0.6970  0.70     0.1343   214.0
# 13902  0.7273  0.66     0.0896   214.0

# %%
x_train, x_test, y_train, y_test = prepare_dataset(df, train_fraction = 0.8)

# %%
# %%time
model = RF(n_estimators = 100)
model.fit(x_train, y_train)
y_pred = model.predict(x_test)
# Out:
# CPU times: user 2.11 s, sys: 34.8 ms, total: 2.15 s
# Wall time: 2.15 s

# %%
metrics_base = compute_metrics(y_test.values, y_pred)
metrics_base
# Out:
# {'MAE': 84.78, 'RMSE': 115.99, 'MAPE': 34.6}

# %%
n = 300
plt.plot(y_test.values[:n], label = 'y_test')
plt.plot(y_pred[:n], label = 'y_pred')
plt.legend()

# %% [markdown]
# # Dummy Model

# %%
y_dummy = y_test.shift(1).fillna(method = 'bfill') #naive or persistance model

# %%
y_dummy
# Out:
# 11122    463.0
# 11123    463.0
# 11124    738.0
# 11125    671.0
# 11126    427.0
#          ...
# 13898    502.0
# 13899    705.0
# 13900    327.0
# 13901    250.0
# 13902    214.0
# Name: target, Length: 2781, dtype: float64

# %%
y_test
# Out:
# 11122    463.0
# 11123    738.0
# 11124    671.0
# 11125    427.0
# 11126    286.0
#          ...
# 13898    705.0
# 13899    327.0
# 13900    250.0
# 13901    214.0
# 13902    214.0
# Name: target, Length: 2781, dtype: float64

# %%
metrics_dummy = compute_metrics(y_test.values, y_dummy)

# %%
metrics_dummy
# Out:
# {'MAE': 87.01, 'RMSE': 128.17, 'MAPE': 55.4}

# %%
metrics_base
# Out:
# {'MAE': 84.78, 'RMSE': 115.99, 'MAPE': 34.6}
